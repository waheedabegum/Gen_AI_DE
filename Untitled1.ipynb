# %% [markdown]
# <a href="https://colab.research.google.com/github/waheedabegum/Gen_AI_DE/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
ner = pipeline("ner", grouped_entities = True)#this is task , below one is model
text = "Abdul Kalam is a great president . he worked for nasa"
entities = ner(text)
print(entities) # if you remve grouped entities , you will not see the same output

# %%
from transformers import pipeline
ner = pipeline(model="vblagoje/bert-english-uncased-finetuned-pos")
text = "Abdul Kalam is a great president . he worked for nasa"
entities = ner(text)
print(entities) # if you remve grouped entities , you will not see the same output

# %%
from transformers import pipeline
ner = pipeline("fill-mas",model="bert-base-uncased")
text = "Abdul Kalam is a great [MASK] . he worked for [MASK]"
entities = ner(text)
print(entities) # if you remve grouped entities , you will not see the same output

# %%
from transformers import pipeline
ner = pipeline("text-generation",model="gpt2")
text = "Abdul Kalam is a ,"
entities = ner(text,max_length=50,num_return_sequences=1)
print(entities) # if you remve grouped entities , you will not see the same output
